# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep24032004/Data-Science-Assignment-eCommerce-Transactions-Dataset/blob/main/Maggala_Pradeep_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load datasets
customers = pd.read_csv('Customers.csv')
products = pd.read_csv('Products.csv')
transactions = pd.read_csv('Transactions.csv')

# %%
# Display first few rows to understand the structure
print("Customers Dataset:")
print(customers.head())
# Out:
# Customers Dataset:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15

# %%
print("\nProducts Dataset:")
print(products.head())
# Out:
# Products Dataset:
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31

# %%
print("\nTransactions Dataset:")
print(transactions.head())
# Out:
# Transactions Dataset:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue   Price
# 0      300.68  300.68
# 1      300.68  300.68
# 2      300.68  300.68
# 3      601.36  300.68
# 4      902.04  300.68

# %%
# Data Overview
print("\nCustomers Info:")
print(customers.info())
# Out:
# Customers Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB
# None

# %%
print("\nProducts Info:")
print(products.info())
# Out:
# Products Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.3+ KB
# None

# %%
print("\nTransactions Info:")
print(transactions.info())
# Out:
# Transactions Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price            1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB
# None

# %%
# Checking for missing values
print("\nMissing Values:")
print("Customers:", customers.isnull().sum())
print("Products:", products.isnull().sum())
print("Transactions:", transactions.isnull().sum())
# Out:
# Missing Values:
# Customers: CustomerID      0
# CustomerName    0
# Region          0
# SignupDate      0
# dtype: int64
# Products: ProductID      0
# ProductName    0
# Category       0
# Price          0
# dtype: int64
# Transactions: TransactionID      0
# CustomerID         0
# ProductID          0
# TransactionDate    0
# Quantity           0
# TotalValue         0
# Price              0
# dtype: int64

# %%
# Basic statistics
print("\nBasic Statistics:")
print("Transactions:")
print(transactions.describe())
# Out:
# Basic Statistics:
# Transactions:
#           Quantity   TotalValue       Price
# count  1000.000000  1000.000000  1000.00000
# mean      2.537000   689.995560   272.55407
# std       1.117981   493.144478   140.73639
# min       1.000000    16.080000    16.08000
# 25%       2.000000   295.295000   147.95000
# 50%       3.000000   588.880000   299.93000
# 75%       4.000000  1011.660000   404.40000
# max       4.000000  1991.040000   497.76000

# %%
# Merge datasets for combined analysis
merged_data = transactions.merge(customers, on='CustomerID').merge(products, on='ProductID')
print("\nMerged Data Sample:")
print(merged_data.head())
# Out:
# Merged Data Sample:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue  Price_x     CustomerName         Region  SignupDate  \
# 0      300.68   300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68   300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68   300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36   300.68  Travis Campbell  South America  2024-04-11
# 4      902.04   300.68    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category  Price_y
# 0  ComfortLiving Bluetooth Speaker  Electronics   300.68
# ...

# %%
# EDA
# 1. Distribution of customers by region
sns.countplot(data=customers, x='Region', palette='viridis')
plt.title('Number of Customers by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-12-517082f1b853>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=customers, x='Region', palette='viridis')

# %%
# 2. Top-selling products
top_products = merged_data.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='bar', color='skyblue')
plt.title('Top 10 Best-Selling Products')
plt.xlabel('Product Name')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Total sales by category
category_sales = merged_data.groupby('Category')['TotalValue'].sum().sort_values(ascending=False)
category_sales.plot(kind='bar', color='lightgreen')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales (USD)')
plt.xticks(rotation=45)
plt.show()

# %%
# 4. Monthly sales trends
merged_data['TransactionDate'] = pd.to_datetime(merged_data['TransactionDate'])
merged_data['MonthYear'] = merged_data['TransactionDate'].dt.to_period('M')
monthly_sales = merged_data.groupby('MonthYear')['TotalValue'].sum()
monthly_sales.plot(kind='line', marker='o', color='orange')
plt.title('Monthly Sales Trends')
plt.xlabel('Month-Year')
plt.ylabel('Total Sales (USD)')
plt.xticks(rotation=45)
plt.show()

# %%
# 5. Top regions by total sales
region_sales = merged_data.groupby('Region')['TotalValue'].sum().sort_values(ascending=False)
region_sales.plot(kind='bar', color='purple')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales (USD)')
plt.xticks(rotation=45)
plt.show()

# %%
# Business Insights
insights = [
    "1. North America has the highest number of customers, indicating a strong customer base in this region.",
    "2. Product X (top product from analysis) is the most sold item, contributing significantly to revenue.",
    "3. Electronics category drives the highest sales, suggesting it is the most profitable segment.",
    "4. Sales show a seasonal trend with peaks in December, likely due to holiday shopping.",
    "5. North America also leads in total sales, emphasizing the importance of focusing marketing efforts there."
]

# %%
# Print insights
print("\nBusiness Insights:")
for insight in insights:
    print(insight)
# Out:
# Business Insights:
# 1. North America has the highest number of customers, indicating a strong customer base in this region.
# 2. Product X (top product from analysis) is the most sold item, contributing significantly to revenue.
# 3. Electronics category drives the highest sales, suggesting it is the most profitable segment.
# 4. Sales show a seasonal trend with peaks in December, likely due to holiday shopping.
# 5. North America also leads in total sales, emphasizing the importance of focusing marketing efforts there.

# %%
# !pip install fpdf
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=13b53e3775dd498471ccad4b08649fcee5b13818b81b7b3f8621e980392b8847
#   Stored in directory: /root/.cache/pip/wheels/65/4f/66/bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built fpdf
# ...

# %%
# Save insights to a PDF report
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)
pdf.cell(200, 10, txt="Business Insights Report", ln=True, align='C')

for insight in insights:
    pdf.multi_cell(0, 10, txt=insight)

pdf.output("Business_Insights_Report.pdf")
# Out:
# ''

# %%
# Save the merged dataset for future analysis
merged_data.to_csv('Merged_Dataset.csv', index=False)
